# %% [markdown]
# # 04 — Compute movement metrics

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parents[2]
sys.path.insert(0, str(repo_root / 'telemetry'))

data_dir = repo_root / 'telemetry' / 'data' / 'raw' / 'psat-situk-2018-2020'
track_csv = data_dir / 'ATN_steelhead_tracks_10.6.2021.csv'
metadata_csv = data_dir / 'Seitz_ATN Tag Deployment Metadata_steelhead kelts_10.7.2021.csv'

# %%
from src.io.load_tracks import load_track_csv
from src.tracks.metrics import compute_step_metrics, summarize_track_metrics

tracks_df, _ = load_track_csv(track_csv)
step_metrics = compute_step_metrics(tracks_df)
summary_metrics = summarize_track_metrics(step_metrics)

step_metrics.head(), summary_metrics.head()
# Out:
# (   fish_id                 timestamp   latitude   longitude  prev_latitude  \
#  0   169144 2018-05-31 00:00:00+00:00  59.375000 -139.650000            NaN
#  1   169144 2018-06-01 00:00:00+00:00  59.375000 -139.783333      59.375000
#  2   169144 2018-06-02 00:00:00+00:00  59.358333 -139.941667      59.375000
#  3   169144 2018-06-03 00:00:00+00:00  59.350000 -140.150000      59.358333
#  4   169144 2018-06-04 00:00:00+00:00  59.337500 -140.550000      59.350000
#
#     prev_longitude            prev_timestamp  bearing_deg  \
#  0             NaN                       NaT          NaN
#  1     -139.650000 2018-05-31 00:00:00+00:00   270.057368
#  2     -139.783333 2018-06-01 00:00:00+00:00   258.415773
#  3     -139.941667 2018-06-02 00:00:00+00:00   265.610462
#  4     -140.150000 2018-06-03 00:00:00+00:00   266.671014
#
#     daily_displacement_km  step_days  speed_km_day  cumulative_distance_km
#  0                    NaN        NaN           NaN                     NaN
#  1               7.579879        1.0      7.579879                7.579879
#  2               9.192772        1.0      9.192772               16.772650
#  3              11.887125        1.0     11.887125               28.659775
#  4              22.803080        1.0     22.803080               51.462855  ,
#     fish_id  n_observations               track_start  \
#  0   169144              88 2018-05-31 00:00:00+00:00
#  1   169146              51 2018-05-30 00:00:00+00:00
#  2   169154              25 2018-05-29 00:00:00+00:00
#  3   175618              29 2018-05-30 00:00:00+00:00
#  4   176929              45 2019-06-02 00:00:00+00:00
#
#                    track_end  track_duration_days  cumulative_distance_km  \
#  0 2018-08-26 00:00:00+00:00                 87.0             3245.782618
#  1 2018-07-19 00:00:00+00:00                 50.0              806.474940
#  2 2018-06-22 00:00:00+00:00                 24.0              407.772245
#  3 2018-06-27 00:00:00+00:00                 28.0              473.517135
#  4 2019-07-16 00:00:00+00:00                 44.0              561.627780
#
#     mean_speed_km_day
#  0          37.307846
#  1          16.129499
#  2          16.990510
#  3          16.911326
#  4          12.764268  )

# %% [markdown]
# # 01 — Load and validate tracks

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parents[2]
sys.path.insert(0, str(repo_root / 'telemetry'))

data_dir = repo_root / 'telemetry' / 'data' / 'raw' / 'psat-situk-2018-2020'
track_csv = data_dir / 'ATN_steelhead_tracks_10.6.2021.csv'
metadata_csv = data_dir / 'Seitz_ATN Tag Deployment Metadata_steelhead kelts_10.7.2021.csv'

# %%
from src.io.load_tracks import load_track_csv, to_geodataframe

tracks_df, report = load_track_csv(track_csv)
tracks_gdf = to_geodataframe(tracks_df)

report, tracks_df.head(), tracks_gdf.crs
# Out:
# (ValidationReport(input_rows=2058, output_rows=1901, dropped_rows=157, malformed_dates=0, invalid_latitudes=0, invalid_longitudes=157),
#     fish_id                 timestamp   latitude   longitude
#  0   169144 2018-05-31 00:00:00+00:00  59.375000 -139.650000
#  1   169144 2018-06-01 00:00:00+00:00  59.375000 -139.783333
#  2   169144 2018-06-02 00:00:00+00:00  59.358333 -139.941667
#  3   169144 2018-06-03 00:00:00+00:00  59.350000 -140.150000
#  4   169144 2018-06-04 00:00:00+00:00  59.337500 -140.550000,
#  <Geographic 2D CRS: EPSG:4326>
#  Name: WGS 84
#  Axis Info [ellipsoidal]:
#  - Lat[north]: Geodetic latitude (degree)
#  - Lon[east]: Geodetic longitude (degree)
#  Area of Use:
#  - name: World.
#  - bounds: (-180.0, -90.0, 180.0, 90.0)
#  Datum: World Geodetic System 1984 ensemble
#  - Ellipsoid: WGS 84
#  - Prime Meridian: Greenwich)
